# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
def populate_data(csv_name, test_percent=0.3):
    df = pd.read_csv(csv_name)

    train, test = train_test_split(df, test_size=test_percent)

    return train, test

# %%
def system_entropy(df, target_column):
    count_dict = dict(df[target_column].value_counts())
    unique_vals = (list(set(count_dict.keys())))
    total_len = len(df[target_column])

    sys_entropy = 0
    for value in unique_vals:
        sys_entropy = sys_entropy + (-(count_dict[value] / total_len) * np.log2((count_dict[value] / total_len)))
    return sys_entropy

# %%
def entropy(df, target_column, query_column):
    tiny = 0.0000000000001

    list1 = df.groupby([query_column, target_column]).size().reset_index(name="combo_count")
    list2 = df.groupby([query_column]).size().reset_index(name="var_count")

    list1['var_count'] = list1[query_column].map(dict(list2[[query_column, 'var_count']].values))

    list1['entropy'] = -(list1['combo_count'] / (list1['var_count'] + tiny)) * \
                   np.log2((list1['combo_count'] / (list1['var_count'] + tiny)))

    return np.abs(np.sum(list1['entropy']))

# %%
def max_information_gain(df, target_column):
    col_list = list(df.columns)
    col_list.remove(target_column)

    column_entropy = {}
    for col in col_list:
        column_entropy[col] = entropy(df, target_column, col)
    max_entropy_key = max(column_entropy, key=column_entropy.get)
    return max_entropy_key, column_entropy[max_entropy_key]

# %%
def build_tree(df, target_column, tree_depth=0, max_depth=6):
    tree_depth = tree_depth + 1
    max_ent_key, max_ent_val = max_information_gain(df, target_column)
    max_ent_vals = np.unique(df[max_ent_key])
    tree_struct = {}
    for value in max_ent_vals:
        choice_name = max_ent_key + "_" + str(value)
        #print("choicename", choice_name)
        # return
        only_val = df[df[max_ent_key] == value].reset_index(drop=True)
        #only_val = only_val.drop(max_ent_key, axis=1)
        #print("onlyvals", only_val)
        # print("dropping", max_ent_key)
        # print(only_val)
        # break
        target_vals, target_counts = np.unique(only_val[target_column],return_counts=True)
        if tree_depth >= max_depth:
            index_max = max(range(len(target_counts)), key=target_counts.__getitem__)
            choice = target_vals[index_max]
            #print("depth vote", choice)
            # print("target_vals", target_vals)
            # print("target_counts", target_counts)
            # #print('dataframe', df)
            # print("target_column", target_column)
            tree_struct[choice_name] = choice
        elif len(target_counts) == 1:
            #print("non depth vote", target_vals[0])
            tree_struct[choice_name] = target_vals[0]
        else:
            tree_struct[choice_name] = build_tree(only_val, target_column, tree_depth, max_depth)

    return tree_struct

# %%
import collections
def get_tree_vote_list(tree):
    vote_list = []
    if isinstance(tree, dict):
        for key in tree.keys():
            sub_votes = get_tree_vote_list(tree[key])
            if isinstance(sub_votes, list):
                for vote in sub_votes:
                    vote_list.append(vote)
            else:
                vote_list.append(sub_votes)
    elif isinstance(tree, str):
        vote_list.append(tree)
    if len(vote_list) < 1:
        print("votelist tree", tree)
    return vote_list

def get_tree_vote(tree):
    vote_list = get_tree_vote_list(tree)
    occurrences = collections.Counter(vote_list)
    max_key = max(occurrences, key=occurrences.get)
    return max_key

# %%
def search_tree(row_dict, tree_to_search, search_depth=0):
    row_keys = []
    for entry in row_dict.keys():
        new_key = entry + "_" +  str(row_dict[entry])
        row_keys.append(new_key)

    if not isinstance(tree_to_search, dict):
        # print("Found Key")
        return tree_to_search

    key_list = list(tree_to_search.keys())
    found_key = False
    # print("Key list:", key_list)
    # print("Row Keys:", row_keys)
    for key in row_keys:
        #print("key:", key)
        if key in key_list:
            return search_tree(row_dict, tree_to_search[key],
                               search_depth=(search_depth+1))
    if not found_key:
        #print("Didn't find key", tree_to_search)
        return get_tree_vote(tree_to_search)

# %%
def max_depth(query_tree):
    max_num = 0
    if isinstance(query_tree, dict):
        for key in query_tree.keys():
            key_depth = max_depth(query_tree[key])
            if max_num < key_depth:
                max_num = key_depth
        max_num = max_num + 1
        return max_num
    else:
        return 0

# %%
def get_test_results(test_data, test_tree):
    t = 'acc'
    f = 'unacc'
    tn = 0
    tp = 0
    fn = 0
    fp = 0
    broken = 0

    for index, row in test_data.iterrows():
        answer = search_tree(dict(row), test_tree)
        if answer ==  row['class'] and answer == t:
            tp = tp + 1
        elif answer ==  row['class'] and answer == f:
            tn = tn + 1
        elif answer !=  row['class'] and answer == t:
            fp = fp + 1
        elif answer !=  row['class'] and answer == f:
            fn = fn + 1
        else:
            broken = broken + 1
    total_right = tp + tn
    total_wrong = fp + fn
    total_percent = round((total_right / (total_wrong + total_right)) * 100, 2)
    #print("\t\tTP:", tp, " | TN:", tn, " | FP:", fp, " | FN:", fn, " | Total:", total_percent)
    return tp, tn, fp, fn, total_percent

# %%
depths_to_try = [10]
train_test_to_try = [0.25]
needs_build = True
target_column = 'class'

import time
total_start = time.time()

best_tree_set = {}
from sklearn.model_selection import KFold
kf = KFold(n_splits = 8, shuffle = True, random_state = 2)
train_df, test_df = populate_data('car_evaluation.csv', test_percent=0.25)

# %%
for ttp in train_test_to_try:
    ttp_start = time.time()
    train_df, validation_df = populate_data('car_evaluation.csv', test_percent=ttp)
    best_tree_acc = 0
    best_tree = None
    fold_num = 0
    for train_index, test_index in kf.split(train_df):
        print("\t\tFold Number:", fold_num)
        fold_num = fold_num + 1
        train_set = train_df.iloc[train_index]
        test_set = train_df.iloc[test_index]
        for depth_size in depths_to_try:
            depth_start = time.time()
            print("\t\t\tTrying depth:", depth_size)
            if needs_build:
                usable_tree = build_tree(train_set, target_column, max_depth=depth_size)
            tp, tn, fp, fn, total_percent = get_test_results(test_set, usable_tree)
            print("\t\t\tTP:", tp, " | TN:", tn, " | FP:", fp, " | FN:", fn, " | Total:", total_percent)
            if total_percent > best_tree_acc:
                best_tree = usable_tree
            depth_end = time.time()
            print("\t\t\tDepth took", (depth_end-depth_start), "seconds to train")
    tp, tn, fp, fn, total_percent = get_test_results(validation_df, usable_tree)
    ttp_end = time.time()

    print("*****************************")
    print("Train Test Split:", ttp)
    print("\tValidation Scores - TP:", tp, " | TN:", tn, " | FP:", fp, " | FN:", fn, " | Total:", total_percent)
    print("\tTTS took", (ttp_end-ttp_start), "seconds to train")
    print("*****************************")

    best_tree_set[ttp] = best_tree
        #print("\t\tAnswer List:", answer_list)
        # print("Right:", total_right)
        # print("Wrong:", total_wrong)
        #print("\t\t", depth_size, "percentage correct:", )
print("*****************************")
total_end = time.time()
print("Entire run took:", (total_end - total_start), "seconds")
# Out:
# 		Fold Number: 0
# 			Trying depth: 10
# 			TP: 23  | TN: 76  | FP: 32  | FN: 19  | Total: 66.0
# 			Depth took 45.61134576797485 seconds to train
# 		Fold Number: 1
# 			Trying depth: 10
# 			TP: 21  | TN: 79  | FP: 29  | FN: 19  | Total: 67.57
# 			Depth took 49.0059769153595 seconds to train
# 		Fold Number: 2
# 			Trying depth: 10
# 			TP: 19  | TN: 87  | FP: 34  | FN: 18  | Total: 67.09
# 			Depth took 46.24462556838989 seconds to train
# 		Fold Number: 3
# 			Trying depth: 10
# 			TP: 22  | TN: 88  | FP: 20  | FN: 24  | Total: 71.43
# 			Depth took 49.184141397476196 seconds to train
# 		Fold Number: 4
# 			Trying depth: 10
# 			TP: 29  | TN: 89  | FP: 16  | FN: 21  | Total: 76.13
# 			Depth took 47.79323744773865 seconds to train
# 		Fold Number: 5
# 			Trying depth: 10
# 			TP: 21  | TN: 78  | FP: 39  | FN: 11  | Total: 66.44
# 			Depth took 47.51473951339722 seconds to train
# 		Fold Number: 6
# 			Trying depth: 10
# 			TP: 24  | TN: 92  | FP: 21  | FN: 16  | Total: 75.82
# 			Depth took 53.86616587638855 seconds to train
# 		Fold Number: 7
# 			Trying depth: 10
# 			TP: 17  | TN: 88  | FP: 21  | FN: 27  | Total: 68.63
# 			Depth took 52.66446781158447 seconds to train
# *****************************
# Train Test Split: 0.25
# 	Validation Scores - TP: 65  | TN: 237  | FP: 71  | FN: 43  | Total: 72.6
# 	TTS took 391.9677276611328 seconds to train
# *****************************
# *****************************
# Entire run took: 394.4187800884247 seconds

# %%
print(len(best_tree_set))
for tree in best_tree_set:
    print("Next Tree")
    tp, tn, fp, fn, total_percent = get_test_results(train_df, tree)
    print("\tTrain Set Scores - TP:", tp, " | TN:", tn, " | FP:", fp, " | FN:", fn, " | Total:", total_percent)
# Out:
# 0

# %%
for single_tree in best_tree_set:
    for index, row in test_set.iterrows():
                answer = search_tree(dict(row), usable_tree)
                if answer ==  row['class'] and answer == t:
                    tp = tp + 1
                elif answer ==  row['class'] and answer == f:
                    tn = tn + 1
                elif answer !=  row['class'] and answer == t:
                    fp = fp + 1
                elif answer !=  row['class'] and answer == f:
                    fn = fn + 1
                else:
                    broken = broken + 1
            total_right = tp + tn
            total_wrong = fp + fn
            total_percent = round((total_right / (total_wrong + total_right)) * 100, 2)
            print("\t\tTP:", tp, " | TN:", tn, " | FP:", fp, " | FN:", fn, " | Total:", total_percent)

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = 5, shuffle = True, random_state = 2)
train_df, test_df = populate_data('car_evaluation.csv', test_percent=.1)

for train_index, test_index in kf.split(test_df):
    train = test_df.iloc[train_index]
    test = test_df.iloc[test_index]
    # print("train:", train.shape[0])
    # print("test:", test.shape[0])
    print("\n\ntrain:", train)
    print("\n\ntest:", test)
#Depth 6 - 20% test
# Right: 226
# Wrong: 120
# Percentage: 65.32
# Depth 5 - 30% test
# Right: 381
# Wrong: 138
# Percentage: 73.41
# Depth 25 - 30% test
# Right: 381
# Wrong: 138
# Percentage: 73.41
# Out:
# train:      buying  maint  doors  persons lug_boot safety  class
# 1073    med   high      5        5    small   high    acc
# 1345    low  vhigh      3        5      med    med    acc
# 91    vhigh  vhigh      5        4    small    med  unacc
# 590    high   high      3        5      med   high    acc
# 1485    low   high      5        2    small    low  unacc
# ...     ...    ...    ...      ...      ...    ...    ...
# 1000    med   high      3        2    small    med  unacc
# 1677    low    low      4        2      med    low  unacc
# 688    high    med      3        4      med    med  unacc
# 145   vhigh   high      3        4    small    med  unacc
# 178   vhigh   high      4        4      big    med  unacc
#
# [138 rows x 7 columns]
#
#
# test:      buying  maint  doors  persons lug_boot safety  class
# 1259    med    low      4        4      big   high  vgood
# 840    high    low      5        2      med    low  unacc
# 1029    med   high      4        2      med    low  unacc
# 336   vhigh    low      2        4      med    low  unacc
# 1163    med    med      5        2    small   high  unacc
# 1344    low  vhigh      3        5      med    low  unacc
# 1392    low  vhigh      5        4      big    low  unacc
# 232   vhigh    med      2        4      big    med    acc
# 750    high    med      5        5      med    low  unacc
# 619    high   high      4        5      big    med    acc
# 428   vhigh    low      5        5      med   high    acc
# 1441    low   high      3        4    small    med    acc
# 614    high   high      4        5    small   high    acc
# 1223    med    low      3        2      big   high  unacc
# 584    high   high      3        4      big   high    acc
# 459    high  vhigh      3        2    small    low  unacc
# 1153    med    med      4        5    small    med    acc
# 415   vhigh    low      5        4    small    med  unacc
# 1168    med    med      5        2      big    med  unacc
# 1641    low    low      2        5      med    low  unacc
# 589    high   high      3        5      med    med    acc
# 655    high    med      2        2      big    med  unacc
# 501    high  vhigh      4        4      big    low  unacc
# 92    vhigh  vhigh      5        4    small   high  unacc
# 385   vhigh    low      4        2      big    med  unacc
# 1556    low    med      3        4      big   high  vgood
# 1717    low    low      5        4      big    med   good
# 778    high    low      2        5      med    med  unacc
# 713    high    med      4        4    small   high    acc
# 1381    low  vhigh      5        2      med    med  unacc
# 611    high   high      4        4      big   high    acc
# 973     med   high      2        2    small    med  unacc
# 951     med  vhigh      5        2      big    low  unacc
# 63    vhigh  vhigh      4        4    small    low  unacc
# 1526    low    med      2        4      med   high   good
#
#
# train:      buying  maint  doors  persons lug_boot safety  class
# 1345    low  vhigh      3        5      med    med    acc
# 1259    med    low      4        4      big   high  vgood
# 840    high    low      5        2      med    low  unacc
# 91    vhigh  vhigh      5        4    small    med  unacc
# 1029    med   high      4        2      med    low  unacc
# ...     ...    ...    ...      ...      ...    ...    ...
# 1000    med   high      3        2    small    med  unacc
# 1677    low    low      4        2      med    low  unacc
# 688    high    med      3        4      med    med  unacc
# 145   vhigh   high      3        4    small    med  unacc
# 178   vhigh   high      4        4      big    med  unacc
#
# [138 rows x 7 columns]
#
#
# test:      buying  maint  doors  persons lug_boot safety  class
# 1073    med   high      5        5    small   high    acc
# 255   vhigh    med      3        4      med    low  unacc
# 347   vhigh    low      2        5      med   high    acc
# 473    high  vhigh      3        4      med   high  unacc
# 647    high   high      5        5      big   high    acc
# 591    high   high      3        5      big    low  unacc
# 1478    low   high      4        5    small   high    acc
# 1222    med    low      3        2      big    med  unacc
# 1518    low    med      2        2      big    low  unacc
# 1048    med   high      4        5      med    med    acc
# 126   vhigh   high      2        5    small    low  unacc
# 1338    low  vhigh      3        4      big    low  unacc
# 102   vhigh  vhigh      5        5      med    low  unacc
# 646    high   high      5        5      big    med    acc
# 1181    med    med      5        5    small   high    acc
# 1635    low    low      2        4      big    low  unacc
# 86    vhigh  vhigh      5        2      med   high  unacc
# 697    high    med      3        5      med    med    acc
# 345   vhigh    low      2        5      med    low  unacc
# 1472    low   high      4        4      med   high  vgood
# 821    high    low      4        4    small   high    acc
# 986     med   high      2        4      med   high    acc
# 1356    low  vhigh      4        2      big    low  unacc
# 541    high   high      2        2    small    med  unacc
# 1411    low   high      2        2      big    med  unacc
# 746    high    med      5        4      big   high    acc
# 1188    med    low      2        2    small    low  unacc
# 1451    low   high      3        5    small   high    acc
# 113   vhigh   high      2        2      med   high  unacc
# 942     med  vhigh      4        5      big    low  unacc
# 1047    med   high      4        5      med    low  unacc
# 1158    med    med      4        5      big    low  unacc
# 571    high   high      3        2      med    med  unacc
# 417   vhigh    low      5        4      med    low  unacc
# 1522    low    med      2        4    small    med    acc
#
#
# train:      buying  maint  doors  persons lug_boot safety  class
# 1073    med   high      5        5    small   high    acc
# 1259    med    low      4        4      big   high  vgood
# 840    high    low      5        2      med    low  unacc
# 91    vhigh  vhigh      5        4    small    med  unacc
# 1029    med   high      4        2      med    low  unacc
# ...     ...    ...    ...      ...      ...    ...    ...
# 1522    low    med      2        4    small    med    acc
# 377   vhigh    low      3        5      big   high    acc
# 1000    med   high      3        2    small    med  unacc
# 145   vhigh   high      3        4    small    med  unacc
# 178   vhigh   high      4        4      big    med  unacc
#
# [138 rows x 7 columns]
#
#
# test:      buying  maint  doors  persons lug_boot safety  class
# 1345    low  vhigh      3        5      med    med    acc
# 542    high   high      2        2    small   high  unacc
# 1664    low    low      3        4      big   high  vgood
# 949     med  vhigh      5        2      med    med  unacc
# 754    high    med      5        5      big    med    acc
# 705    high    med      4        2      med    low  unacc
# 45    vhigh  vhigh      3        5    small    low  unacc
# 19    vhigh  vhigh      2        5    small    med  unacc
# 1246    med    low      4        2      med    med  unacc
# 1574    low    med      4        2      big   high  unacc
# 74    vhigh  vhigh      4        5    small   high  unacc
# 1581    low    med      4        4      big    low  unacc
# 563    high   high      2        5      med   high    acc
# 1249    med    low      4        2      big    med  unacc
# 189   vhigh   high      5        2    small    low  unacc
# 901     med  vhigh      3        4    small    med  unacc
# 272   vhigh    med      4        2    small   high  unacc
# 370   vhigh    low      3        5    small    med  unacc
# 319   vhigh    med      5        5      med    med    acc
# 1416    low   high      2        4      med    low  unacc
# 756    high    low      2        2    small    low  unacc
# 351   vhigh    low      3        2    small    low  unacc
# 1393    low  vhigh      5        4      big    med    acc
# 1428    low   high      2        5      big    low  unacc
# 1250    med    low      4        2      big   high  unacc
# 35    vhigh  vhigh      3        2      big   high  unacc
# 262   vhigh    med      3        5    small    med  unacc
# 186   vhigh   high      4        5      big    low  unacc
# 1405    low   high      2        2    small    med  unacc
# 442    high  vhigh      2        4    small    med  unacc
# 580    high   high      3        4      med    med  unacc
# 1653    low    low      3        2      big    low  unacc
# 839    high    low      5        2    small   high  unacc
# 1677    low    low      4        2      med    low  unacc
# 688    high    med      3        4      med    med  unacc
#
#
# train:      buying  maint  doors  persons lug_boot safety  class
# 1073    med   high      5        5    small   high    acc
# 1345    low  vhigh      3        5      med    med    acc
# 1259    med    low      4        4      big   high  vgood
# 840    high    low      5        2      med    low  unacc
# 91    vhigh  vhigh      5        4    small    med  unacc
# ...     ...    ...    ...      ...      ...    ...    ...
# 1522    low    med      2        4    small    med    acc
# 377   vhigh    low      3        5      big   high    acc
# 1000    med   high      3        2    small    med  unacc
# 1677    low    low      4        2      med    low  unacc
# 688    high    med      3        4      med    med  unacc
#
# [139 rows x 7 columns]
#
#
# test:      buying  maint  doors  persons lug_boot safety  class
# 1485    low   high      5        2    small    low  unacc
# 1294    med    low      5        5      big    med   good
# 1549    low    med      3        4    small    med    acc
# 477    high  vhigh      3        5    small    low  unacc
# 531    high  vhigh      5        5    small    low  unacc
# 992     med   high      2        5    small   high  unacc
# 140   vhigh   high      3        2      med   high  unacc
# 28    vhigh  vhigh      3        2    small    med  unacc
# 803    high    low      3        5    small   high    acc
# 365   vhigh    low      3        4      med   high    acc
# 1601    low    med      5        2      big   high  unacc
# 324   vhigh    low      2        2    small    low  unacc
# 199   vhigh   high      5        4    small    med  unacc
# 155   vhigh   high      3        5    small   high  unacc
# 452    high  vhigh      2        5    small   high  unacc
# 789    high    low      3        2      big    low  unacc
# 1310    low  vhigh      2        4      med   high    acc
# 1524    low    med      2        4      med    low  unacc
# 982     med   high      2        4    small    med  unacc
# 396   vhigh    low      4        5    small    low  unacc
# 364   vhigh    low      3        4      med    med  unacc
# 1035    med   high      4        4    small    low  unacc
# 806    high    low      3        5      med   high    acc
# 172   vhigh   high      4        4    small    med  unacc
# 796    high    low      3        4      med    med  unacc
# 769    high    low      2        4      med    med  unacc
# 775    high    low      2        5    small    med  unacc
# 1147    med    med      4        4      med    med    acc
# 882     med  vhigh      2        5    small    low  unacc
# 261   vhigh    med      3        5    small    low  unacc
# 1038    med   high      4        4      med    low  unacc
# 356   vhigh    low      3        2      med   high  unacc
# 145   vhigh   high      3        4    small    med  unacc
# 178   vhigh   high      4        4      big    med  unacc
#
#
# train:      buying  maint  doors  persons lug_boot safety  class
# 1073    med   high      5        5    small   high    acc
# 1345    low  vhigh      3        5      med    med    acc
# 1259    med    low      4        4      big   high  vgood
# 840    high    low      5        2      med    low  unacc
# 1029    med   high      4        2      med    low  unacc
# ...     ...    ...    ...      ...      ...    ...    ...
# 1522    low    med      2        4    small    med    acc
# 1677    low    low      4        2      med    low  unacc
# 688    high    med      3        4      med    med  unacc
# 145   vhigh   high      3        4    small    med  unacc
# 178   vhigh   high      4        4      big    med  unacc
#
# [139 rows x 7 columns]
#
#
# test:      buying  maint  doors  persons lug_boot safety  class
# 91    vhigh  vhigh      5        4    small    med  unacc
# 590    high   high      3        5      med   high    acc
# 1505    low   high      5        5    small   high    acc
# 1631    low    low      2        4    small   high   good
# 269   vhigh    med      3        5      big   high    acc
# 960     med  vhigh      5        4      big    low  unacc
# 844    high    low      5        2      big    med  unacc
# 348   vhigh    low      2        5      big    low  unacc
# 246   vhigh    med      3        2      med    low  unacc
# 76    vhigh  vhigh      4        5      med    med  unacc
# 61    vhigh  vhigh      4        2      big    med  unacc
# 977     med   high      2        2      med   high  unacc
# 1050    med   high      4        5      big    low  unacc
# 121   vhigh   high      2        4      med    med  unacc
# 323   vhigh    med      5        5      big   high    acc
# 1720    low    low      5        5    small    med    acc
# 1245    med    low      4        2      med    low  unacc
# 791    high    low      3        2      big   high  unacc
# 1468    low   high      4        4    small    med    acc
# 685    high    med      3        4    small    med  unacc
# 108   vhigh   high      2        2    small    low  unacc
# 1286    med    low      5        4      big   high  vgood
# 1673    low    low      3        5      big   high  vgood
# 1397    low  vhigh      5        5    small   high    acc
# 886     med  vhigh      2        5      med    med  unacc
# 643    high   high      5        5      med    med    acc
# 492    high  vhigh      4        2      big    low  unacc
# 463    high  vhigh      3        2      med    med  unacc
# 245   vhigh    med      3        2    small   high  unacc
# 760    high    low      2        2      med    med  unacc
# 683    high    med      3        2      big   high  unacc
# 321   vhigh    med      5        5      big    low  unacc
# 377   vhigh    low      3        5      big   high    acc
# 1000    med   high      3        2    small    med  unacc

# %%
import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(depth_tree)
# Out:
# {'doors_2': {'maint_high': {'buying_high': {'lug_boot_big': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_small': {'safety_high': 'acc',
#                                                                'safety_low': 'unacc',
#                                                                'safety_med': 'unacc'}},
#                             'buying_low': {'lug_boot_big': {'safety_high': 'unacc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'unacc'},
#                                            'lug_boot_med': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_small': {'safety_high': 'unacc',
#                                                               'safety_low': 'unacc',
#                                                               'safety_med': 'acc'}},
#                             'buying_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'unacc'},
#                                            'lug_boot_small': {'safety_high': 'acc',
#                                                               'safety_low': 'unacc',
#                                                               'safety_med': 'unacc'}},
#                             'buying_vhigh': 'unacc'},
#              'maint_low': {'buying_high': {'lug_boot_big': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_med': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'unacc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'acc',
#                                                               'persons_5': 'unacc'}},
#                            'buying_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'unacc'},
#                                           'lug_boot_med': {'persons_2': 'unacc',
#                                                            'persons_4': 'acc',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'unacc'}},
#                            'buying_med': {'persons_2': 'unacc',
#                                           'persons_4': {'lug_boot_big': 'good',
#                                                         'lug_boot_med': 'good',
#                                                         'lug_boot_small': 'acc'},
#                                           'persons_5': {'lug_boot_big': 'good',
#                                                         'lug_boot_med': 'acc',
#                                                         'lug_boot_small': 'unacc'}},
#                            'buying_vhigh': {'lug_boot_big': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_small': {'safety_high': 'acc',
#                                                                'safety_low': 'unacc',
#                                                                'safety_med': 'unacc'}}},
#              'maint_med': {'buying_high': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'unacc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'unacc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'acc',
#                                                               'persons_5': 'unacc'}},
#                            'buying_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'unacc'},
#                                           'lug_boot_med': {'safety_high': 'good',
#                                                            'safety_low': 'unacc',
#                                                            'safety_med': 'acc'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'unacc'}},
#                            'buying_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'acc',
#                                                            'persons_5': 'acc'},
#                                           'lug_boot_med': {'safety_high': 'acc',
#                                                            'safety_low': 'unacc',
#                                                            'safety_med': 'acc'},
#                                           'lug_boot_small': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'unacc'}},
#                            'buying_vhigh': {'lug_boot_big': {'buying_vhigh': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'unacc',
#                                                              'persons_5': 'unacc'},
#                                             'lug_boot_small': {'persons_2': 'unacc',
#                                                                'persons_4': 'acc',
#                                                                'persons_5': 'unacc'}}},
#              'maint_vhigh': {'buying_high': 'unacc',
#                              'buying_low': {'persons_2': 'unacc',
#                                             'persons_4': {'safety_high': 'acc',
#                                                           'safety_low': 'unacc',
#                                                           'safety_med': 'acc'},
#                                             'persons_5': {'safety_high': 'acc',
#                                                           'safety_low': 'unacc',
#                                                           'safety_med': 'unacc'}},
#                              'buying_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'unacc',
#                                                              'persons_5': 'unacc'},
#                                             'lug_boot_small': {'persons_2': 'unacc',
#                                                                'persons_4': 'unacc',
#                                                                'persons_5': 'unacc'}},
#                              'buying_vhigh': 'unacc'}},
#  'doors_3': {'buying_high': {'maint_high': {'lug_boot_big': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_small': {'persons_2': 'unacc',
#                                                                'persons_4': 'unacc',
#                                                                'persons_5': 'acc'}},
#                              'maint_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'unacc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'acc',
#                                                               'persons_5': 'acc'}},
#                              'maint_med': {'lug_boot_big': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_med': {'persons_2': 'unacc',
#                                                             'persons_4': 'unacc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'unacc',
#                                                               'persons_5': 'unacc'}},
#                              'maint_vhigh': 'unacc'},
#              'buying_low': {'maint_high': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'unacc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'safety_high': 'unacc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'acc',
#                                                               'persons_5': 'acc'}},
#                             'maint_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'unacc',
#                                                            'persons_5': 'unacc'},
#                                           'lug_boot_med': {'persons_2': 'unacc',
#                                                            'persons_4': 'acc',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'}},
#                             'maint_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_med': {'persons_2': 'unacc',
#                                                            'persons_4': 'acc',
#                                                            'persons_5': 'unacc'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'}},
#                             'maint_vhigh': {'persons_2': 'unacc',
#                                             'persons_4': {'buying_low': 'acc'},
#                                             'persons_5': {'lug_boot_big': 'acc',
#                                                           'lug_boot_med': 'unacc',
#                                                           'lug_boot_small': 'acc'}}},
#              'buying_med': {'maint_high': {'lug_boot_big': {'buying_med': 'unacc'},
#                                            'lug_boot_med': {'persons_2': 'unacc',
#                                                             'persons_4': 'unacc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'unacc',
#                                                               'persons_5': 'unacc'}},
#                             'maint_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_med': {'safety_high': 'good',
#                                                            'safety_low': 'unacc',
#                                                            'safety_med': 'acc'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'}},
#                             'maint_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'unacc',
#                                                            'persons_5': 'acc'},
#                                           'lug_boot_med': {'buying_med': 'unacc'},
#                                           'lug_boot_small': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'acc'}},
#                             'maint_vhigh': {'lug_boot_big': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'unacc'},
#                                             'lug_boot_med': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'unacc'},
#                                             'lug_boot_small': {'safety_high': 'acc',
#                                                                'safety_low': 'unacc',
#                                                                'safety_med': 'unacc'}}},
#              'buying_vhigh': {'maint_high': 'unacc',
#                               'maint_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'unacc'},
#                                             'lug_boot_small': {'persons_2': 'unacc',
#                                                                'persons_4': 'acc',
#                                                                'persons_5': 'acc'}},
#                               'maint_med': {'lug_boot_big': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'unacc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_small': {'safety_high': 'acc',
#                                                                'safety_low': 'unacc',
#                                                                'safety_med': 'unacc'}},
#                               'maint_vhigh': 'unacc'}},
#  'doors_4': {'maint_high': {'buying_high': {'lug_boot_big': {'safety_high': 'acc',
#                                                              'safety_med': 'acc'},
#                                             'lug_boot_med': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'acc'},
#                                             'lug_boot_small': {'persons_2': 'unacc',
#                                                                'persons_4': 'acc',
#                                                                'persons_5': 'acc'}},
#                             'buying_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'acc',
#                                                               'persons_5': 'acc'}},
#                             'buying_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_small': {'safety_high': 'acc',
#                                                               'safety_low': 'unacc',
#                                                               'safety_med': 'unacc'}},
#                             'buying_vhigh': 'unacc'},
#              'maint_low': {'buying_high': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'acc',
#                                                               'persons_5': 'unacc'}},
#                            'buying_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_med': {'persons_2': 'unacc',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'good'}},
#                            'buying_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_med': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'}},
#                            'buying_vhigh': {'lug_boot_big': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_small': {'persons_2': 'unacc',
#                                                                'persons_4': 'acc',
#                                                                'persons_5': 'unacc'}}},
#              'maint_med': {'buying_high': {'lug_boot_big': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_med': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'unacc',
#                                                               'persons_5': 'acc'}},
#                            'buying_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_med': {'safety_high': 'vgood',
#                                                            'safety_low': 'unacc',
#                                                            'safety_med': 'good'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'good'}},
#                            'buying_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'acc',
#                                                            'persons_5': 'acc'},
#                                           'lug_boot_med': {'persons_2': 'unacc',
#                                                            'persons_4': 'acc',
#                                                            'persons_5': 'acc'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'}},
#                            'buying_vhigh': {'persons_2': 'unacc',
#                                             'persons_4': {'lug_boot_big': 'acc',
#                                                           'lug_boot_med': 'acc',
#                                                           'lug_boot_small': 'unacc'},
#                                             'persons_5': {'lug_boot_big': 'acc',
#                                                           'lug_boot_med': 'acc',
#                                                           'lug_boot_small': 'unacc'}}},
#              'maint_vhigh': {'lug_boot_big': {'persons_2': 'unacc',
#                                               'persons_4': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'},
#                                               'persons_5': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'}},
#                              'lug_boot_med': {'persons_2': 'unacc',
#                                               'persons_4': {'buying_high': 'unacc',
#                                                             'buying_low': 'acc',
#                                                             'buying_med': 'acc',
#                                                             'buying_vhigh': 'unacc'},
#                                               'persons_5': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'}},
#                              'lug_boot_small': {'buying_high': 'unacc',
#                                                 'buying_low': {'persons_2': 'unacc',
#                                                                'persons_4': 'unacc',
#                                                                'persons_5': 'unacc'},
#                                                 'buying_med': {'persons_2': 'unacc',
#                                                                'persons_4': 'unacc',
#                                                                'persons_5': 'unacc'},
#                                                 'buying_vhigh': 'unacc'}}},
#  'doors_5': {'maint_high': {'buying_high': {'lug_boot_big': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'acc'},
#                                             'lug_boot_med': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'acc'},
#                                             'lug_boot_small': 'unacc'},
#                             'buying_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'safety_high': 'unacc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'acc',
#                                                               'persons_5': 'acc'}},
#                             'buying_med': {'lug_boot_big': {'safety_high': 'acc',
#                                                             'safety_low': 'unacc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_med': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'unacc',
#                                                               'persons_5': 'acc'}},
#                             'buying_vhigh': 'unacc'},
#              'maint_low': {'buying_high': {'lug_boot_big': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_med': {'safety_high': 'acc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'unacc',
#                                                               'persons_5': 'acc'}},
#                            'buying_low': {'lug_boot_big': {'buying_low': 'unacc'},
#                                           'lug_boot_med': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'}},
#                            'buying_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'unacc',
#                                                            'persons_5': 'vgood'},
#                                           'lug_boot_med': {'safety_high': 'unacc',
#                                                            'safety_low': 'unacc',
#                                                            'safety_med': 'good'},
#                                           'lug_boot_small': {'buying_med': 'unacc'}},
#                            'buying_vhigh': {'lug_boot_big': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_med': {'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_small': {'persons_2': 'unacc',
#                                                                'persons_4': 'unacc',
#                                                                'persons_5': 'acc'}}},
#              'maint_med': {'buying_high': {'lug_boot_big': {'safety_high': 'acc',
#                                                             'safety_med': 'acc'},
#                                            'lug_boot_med': {'persons_2': 'unacc',
#                                                             'persons_4': 'acc',
#                                                             'persons_5': 'acc'},
#                                            'lug_boot_small': {'persons_2': 'unacc',
#                                                               'persons_4': 'acc',
#                                                               'persons_5': 'unacc'}},
#                            'buying_low': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'good',
#                                                            'persons_5': 'good'},
#                                           'lug_boot_med': {'safety_high': 'vgood',
#                                                            'safety_low': 'unacc',
#                                                            'safety_med': 'good'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'good',
#                                                              'persons_5': 'acc'}},
#                            'buying_med': {'lug_boot_big': {'persons_2': 'unacc',
#                                                            'persons_4': 'acc',
#                                                            'persons_5': 'acc'},
#                                           'lug_boot_med': {'safety_high': 'vgood',
#                                                            'safety_low': 'unacc',
#                                                            'safety_med': 'acc'},
#                                           'lug_boot_small': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'}},
#                            'buying_vhigh': {'lug_boot_big': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                             'lug_boot_small': {'safety_high': 'acc',
#                                                                'safety_low': 'unacc',
#                                                                'safety_med': 'unacc'}}},
#              'maint_vhigh': {'lug_boot_big': {'buying_high': 'unacc',
#                                               'buying_low': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                               'buying_med': {'persons_2': 'unacc',
#                                                              'persons_4': 'acc',
#                                                              'persons_5': 'acc'},
#                                               'buying_vhigh': 'unacc'},
#                              'lug_boot_med': {'buying_high': 'unacc',
#                                               'buying_low': {'safety_high': 'acc',
#                                                              'safety_low': 'unacc',
#                                                              'safety_med': 'acc'},
#                                               'buying_med': {'safety_low': 'unacc',
#                                                              'safety_med': 'acc'},
#                                               'buying_vhigh': 'unacc'},
#                              'lug_boot_small': {'buying_high': 'unacc',
#                                                 'buying_low': {'persons_2': 'unacc',
#                                                                'persons_4': 'unacc',
#                                                                'persons_5': 'acc'},
#                                                 'buying_med': {'persons_2': 'unacc',
#                                                                'persons_4': 'unacc',
#                                                                'persons_5': 'acc'},
#                                                 'buying_vhigh': 'unacc'}}}}

# %%
test_dict = {'door':{'2':{'maint':{'high':'nahFam'}}, '3':{'maint':{'med':'yeahFam'}},
                     '4':{'maint':{'med':'waycool'}}, '5':{'maint':{'low':'OMFG'}}}}
def print_layer(layer_dict, tab_string=""):
    if not isinstance(layer_dict, dict):
        print(layer_dict)
        return
    tab_string = tab_string + "\t"
    for layer in layer_dict.keys():
        if isinstance(layer_dict[layer], dict):
            print(tab_string, layer, ":", list(layer_dict[layer].keys()))
            print_layer(layer_dict[layer], tab_string)
        else:
            print(tab_string, layer, ":", layer_dict[layer])


print_layer(depth_tree)
# Out:
# 	 doors_2 : ['maint_high', 'maint_low', 'maint_med', 'maint_vhigh']
# 		 maint_high : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['persons_2', 'persons_4', 'persons_5']
# 				 persons_2 : unacc
# 				 persons_4 : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 persons_5 : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 					 lug_boot_big : acc
# 					 lug_boot_med : unacc
# 					 lug_boot_small : unacc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['buying_low']
# 					 buying_low : unacc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 			 buying_vhigh : unacc
# 		 maint_low : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['buying_high']
# 					 buying_high : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : unacc
# 			 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 				 persons_2 : unacc
# 				 persons_4 : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 					 lug_boot_big : good
# 					 lug_boot_med : acc
# 					 lug_boot_small : acc
# 				 persons_5 : ['buying_low']
# 					 buying_low : unacc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : unacc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : good
# 				 lug_boot_small : ['buying_med']
# 					 buying_med : unacc
# 			 buying_vhigh : ['safety_high', 'safety_low', 'safety_med']
# 				 safety_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 					 lug_boot_big : acc
# 					 lug_boot_med : acc
# 					 lug_boot_small : unacc
# 				 safety_low : unacc
# 				 safety_med : ['lug_boot_big', 'lug_boot_med']
# 					 lug_boot_big : acc
# 					 lug_boot_med : unacc
# 		 maint_med : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 lug_boot_small : ['buying_high']
# 					 buying_high : unacc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : unacc
# 					 safety_low : unacc
# 					 safety_med : acc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : unacc
# 					 safety_low : unacc
# 					 safety_med : acc
# 			 buying_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 		 maint_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 			 lug_boot_big : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 				 buying_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 buying_vhigh : unacc
# 			 lug_boot_med : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 buying_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : unacc
# 				 buying_vhigh : unacc
# 			 lug_boot_small : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 				 buying_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 				 buying_vhigh : unacc
# 	 doors_3 : ['maint_high', 'maint_low', 'maint_med', 'maint_vhigh']
# 		 maint_high : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : unacc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : unacc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 			 buying_vhigh : unacc
# 		 maint_low : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : unacc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : good
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : good
# 					 safety_low : unacc
# 					 safety_med : acc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : good
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 			 buying_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 		 maint_med : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['buying_high']
# 					 buying_high : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : unacc
# 					 safety_low : unacc
# 					 safety_med : good
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : good
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 			 buying_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['buying_vhigh']
# 					 buying_vhigh : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 		 maint_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 			 lug_boot_big : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 buying_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 buying_vhigh : unacc
# 			 lug_boot_med : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 buying_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 buying_vhigh : unacc
# 			 lug_boot_small : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 				 buying_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 				 buying_vhigh : unacc
# 	 doors_4 : ['maint_high', 'maint_low', 'maint_med', 'maint_vhigh']
# 		 maint_high : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : unacc
# 			 buying_vhigh : unacc
# 		 maint_low : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : unacc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : unacc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : good
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 			 buying_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_4', 'persons_5']
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : unacc
# 		 maint_med : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['buying_low']
# 					 buying_low : unacc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : vgood
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_4', 'persons_5']
# 					 persons_4 : unacc
# 					 persons_5 : unacc
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 			 buying_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 		 maint_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 			 lug_boot_big : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 buying_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 buying_vhigh : unacc
# 			 lug_boot_med : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 buying_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 buying_vhigh : unacc
# 			 lug_boot_small : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 buying_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 				 buying_vhigh : unacc
# 	 doors_5 : ['maint_high', 'maint_low', 'maint_med', 'maint_vhigh']
# 		 maint_high : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 				 lug_boot_small : ['buying_low']
# 					 buying_low : acc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low']
# 					 safety_high : acc
# 					 safety_low : unacc
# 				 lug_boot_med : ['buying_med']
# 					 buying_med : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : unacc
# 			 buying_vhigh : unacc
# 		 maint_low : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : acc
# 			 buying_low : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : unacc
# 					 safety_low : unacc
# 					 safety_med : good
# 				 lug_boot_small : ['buying_low']
# 					 buying_low : unacc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : good
# 					 persons_5 : good
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : vgood
# 					 persons_5 : good
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : unacc
# 					 safety_low : unacc
# 					 safety_med : acc
# 			 buying_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : unacc
# 					 persons_5 : unacc
# 		 maint_med : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 			 buying_high : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : unacc
# 			 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 				 persons_2 : unacc
# 				 persons_4 : ['buying_low']
# 					 buying_low : unacc
# 				 persons_5 : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 					 lug_boot_big : good
# 					 lug_boot_med : good
# 					 lug_boot_small : acc
# 			 buying_med : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : vgood
# 					 persons_5 : acc
# 				 lug_boot_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 lug_boot_small : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 			 buying_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 				 lug_boot_big : ['buying_vhigh']
# 					 buying_vhigh : acc
# 				 lug_boot_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 lug_boot_small : ['persons_4', 'persons_5']
# 					 persons_4 : unacc
# 					 persons_5 : unacc
# 		 maint_vhigh : ['lug_boot_big', 'lug_boot_med', 'lug_boot_small']
# 			 lug_boot_big : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 buying_med : ['safety_high', 'safety_low', 'safety_med']
# 					 safety_high : acc
# 					 safety_low : unacc
# 					 safety_med : acc
# 				 buying_vhigh : unacc
# 			 lug_boot_med : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['buying_low']
# 					 buying_low : unacc
# 				 buying_med : ['buying_med']
# 					 buying_med : acc
# 				 buying_vhigh : unacc
# 			 lug_boot_small : ['buying_high', 'buying_low', 'buying_med', 'buying_vhigh']
# 				 buying_high : unacc
# 				 buying_low : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : unacc
# 				 buying_med : ['persons_2', 'persons_4', 'persons_5']
# 					 persons_2 : unacc
# 					 persons_4 : acc
# 					 persons_5 : acc
# 				 buying_vhigh : unacc

# %%
class Node:
    def __init__(self, choice="", options=[], final_result=None, parent=None, is_leaf=False):
        self.choice = choice
        self.options = options
        self.final_result = final_result
        self.is_leaf = is_leaf
        self.parent = parent

    def add_key(self, key):
        self.choice = key

    def add_option(self, option):
        self.options.append(option)

    def add_options(self, options):
        for option in options:
            self.add_option(option)

    def get_verdict(self):
        return self.final_result

    def set_verdict(self, verdict):
        self.final_result = verdict
